# %%
"""
{"2006": {"Flevoland": 
                {"noordoostpolder": "22", 
                 "urk": "32", 
                 "lelystad": "20", 
                  "almere": "23", 
                  "dronten": "21", 
                  "zeewolde": "26"
                  "__provdata": {
                              "min": ["lelystad", "20"], 
                              "max": ["urk", "32"], 
                              "avg": "24"
                            }
          "__countrydata":
                   {"min": "Flevoland",
                    "max": "Zeeland",
                    "avg": "39"}
"""

#var["2006"][["__countrydata"]["min"]]["__provdata"]["min"]
print

# %%
import pandas as pd
import json
import csv
import glob
import os


def list_columns(year, location):
	"""
	Returns all columns of a specific year.csv file.
	This file is identical to the .xls file provided by the CBS,
	but is converted to CSV format.
	"""
	return sorted(pd.DataFrame.from_csv(location + \
					str(year) + ".csv").columns)

def get_vars(csvfile):
    """
    Returns a dictionary of correct variables for a specific year.
    """
    with open(csvfile, "rbU") as f:
        reader = reader=csv.reader(f, delimiter=';')
        return {row[0]:row[1] for row in reader}

# Dictionary of correct variables for all years.
variables = {os.path.basename(fn)[:-4]: get_vars(fn)
				for fn in glob.glob('data/csv/vars/*')
				if not fn.endswith("~")}

# List of all provinces.
provinces = ["Groningen", "Friesland", "Drenthe", "Overijssel",
            "Flevoland", "Gelderland", "Utrecht", "Noord-Holland",
             "Zuid-Holland", "Zeeland", "Noord-Brabant", "Limburg"]

def get_json(var, variables, provinces, years, location = "data/csv/"):
    """
    Returns a json string per item,
    in which the data for the given years is included.

    var: string
    variables: nested dictionary
    provinces: list of Dutch provinces
    years: tuple -> ints
    location: string

    E.g.

    > get_json("aantal_mannen", variables, provinces, (2010, 2014))
    >>> {'2010': {'Drenthe':  { u'Aa en Hunze': 12685,
								u'Assen': 32605,
								...
							  },
				 'Flevoland': {u'Almere': 93510,
							   u'Dronten': 20185,
							   ...
							  }
				 },

		 '2011': {...
		 }
    """

    JSON = {}

    # For each year provided in the years tuple parameter...
    for year in xrange(years[0], years[1] + 1):
		# Create a new entry in the JSON dict.

        year = str(year)
        JSON[year] = {}

        # Retrieve correct variable names.
        item = variables[var][year]
        areades = variables["regioaanduiding"][year]
        index = variables["regionaam"][year]
        data = pd.DataFrame.from_csv(location + year + ".csv")

        # Lower all input and all columns
        # (CBS uses multicase for its columns throughout the years).
        item, areades = item.lower(), areades.lower()
        index = index.lower()
        data.columns = map(str.lower, data.columns)

        # First select only all gemeentes,
        # then filter based on given item and index.
        # This will be for all gemeentes in all provinces.
        root = data[(data[areades] == 'Gemeente') |
                    (data[areades] == 'G')].filter([item, index])
                    
        # If var is float, multiply by 100.
        if var == "gemiddelde_huishoudensgrootte" or var == "personenautos_per_huishouden":
            root[item] = root[item].apply(lambda x: float(x.replace(',', '.'))*100 if x != "x" else 'x')

        # DataFrame consisting of Gemeente,Provincie data.
        # Foor 2004 and 2005, assuming data is equal to 2006 data,
        # because of nonexistence of data for these years.
        try:
            gemprov = pd.DataFrame.from_csv(location +
                                            "gemprov/" + year + ".csv")
        except Exception as e:
            gemprov = pd.DataFrame.from_csv(location +
                                            "gemprov/2006.csv")

        # For each province in the provinces list parameter...
        for prov in provinces:
            # Create a list of Gemeentes in currently iterated province.
            gem = list(gemprov[(gemprov["PROVINCIE"] == prov)]
                       .filter(["GEMEENTE"]).T.columns)

            # Filter root based on this list.
            branch = root[(root[index].isin(gem))].set_index([index])

            # Lowercase all Gemeente names.
            branch.index = branch.index.str.lower()

            # Write to JSON dictionary.
            JSON[year][prov] = json.loads(branch[item].to_json())

    return JSON

# %%
get_json("aantal_mannen", variables, provinces, (2010, 2014))
# Out:
# {'2010': {'Drenthe': {u'aa en hunze': 12685,
#    u'assen': 32605,
#    u'borger-odoorn': 13035,
#    u'coevorden': 17995,
#    u'de wolden': 11805,
#    u'emmen': 54130,
#    u'hoogeveen': 27170,
#    u'meppel': 15790,
#    u'midden-drenthe': 16750,
#    u'noordenveld': 15240,
#    u'tynaarlo': 15915,
#    u'westerveld': 9660},
#   'Flevoland': {u'almere': 93510,
#    u'dronten': 20185,
#    u'lelystad': 37270,
#    u'noordoostpolder': 23360,
#    u'urk': 9245,
#    u'zeewolde': 10620},
#   'Friesland': {u'achtkarspelen': 14265,
#    u'ameland': 1760,
#    u'boarnsterhim': 9765,
#    u'bolsward': 4855,
#    u'dantumadiel': 9670,
#    u'dongeradeel': 12235,
#    u'ferwerderadiel': 4535,
#    u'franekeradeel': 10395,
#    u'gaasterl\xe2n-sleat': 5220,
#    u'harlingen': 7905,
#    u'heerenveen': 21325,
#    u'het bildt': 5595,
#    u'kollumerland en nieuwkruisland': 6660,
#    u'leeuwarden': 45915,
#    u'leeuwarderadeel': 5275,
#    u'lemsterland': 6930,
#    u'littenseradiel': 5555,
#    u'menaldumadeel': 6970,
#    u'nijefurd': 5435,
#    u'ooststellingwerf': 13155,
#    u'opsterland': 14995,
#    u'schiermonnikoog': 465,
#    u'skarsterl\xe2n': 13685,
#    u'smallingerland': 27410,
#    u'sneek': 16455,
#    u'terschelling': 2480,
#    u'tytsjerksteradiel': 16115,
#    u'vlieland': 585,
#    u'weststellingwerf': 12955,
#    u'wymbritseradiel': 8300,
#    u'w\xfbnseradiel': 6055},
#   'Gelderland': {u'aalten': 13765,
#    u'apeldoorn': 76755,
#    u'arnhem': 72965,
#    u'barneveld': 26100,
#    u'berkelland': 22645,
#    u'beuningen': 12755,
#    u'bronckhorst': 18715,
#    u'brummen': 10440,
#    u'buren': 12950,
#    u'culemborg': 13635,
#    u'doesburg': 5675,
#    u'doetinchem': 27745,
#    u'druten': 9000,
#    u'duiven': 12550,
#    u'ede': 52850,
#    u'elburg': 10930,
#    u'epe': 16210,
#    u'ermelo': 12920,
#    u'geldermalsen': 13015,
#    u'groesbeek': 9235,
#    u'harderwijk': 21670,
#    u'hattem': 5755,
#    u'heerde': 9040,
#    u'heumen': 8240,
#    u'lingewaal': 5455,
#    u'lingewaard': 22565,
#    u'lochem': 16405,
#    u'maasdriel': 11970,
#    u'millingen aan de rijn': 2955,
#    u'montferland': 17550,
#    u'neder-betuwe': 11235,
#    u'neerijnen': 6020,
#    u'nijkerk': 19680,
#    u'nijmegen': 78095,
#    u'nunspeet': 13175,
#    u'oldebroek': 11545,
#    u'oost gelre': 15265,
#    u'oude ijsselstreek': 19950,
#    u'overbetuwe': 22635,
#    u'putten': 11680,
#    u'renkum': 15275,
#    u'rheden': 21230,
#    u'rijnwaarden': 5530,
#    u'rozendaal': 750,
#    u'scherpenzeel': 4625,
#    u'tiel': 20470,
#    u'ubbergen': 4580,
#    u'voorst': 11860,
#    u'wageningen': 18190,
#    u'west maas en waal': 9185,
#    u'westervoort': 7565,
#    u'wijchen': 19845,
#    u'winterswijk': 14440,
#    u'zaltbommel': 13165,
#    u'zevenaar': 15695,
#    u'zutphen': 22790},
#   'Groningen': {u'appingedam': 5790,
#    u'bedum': 5245,
#    u'bellingwedde': 4640,
#    u'de marne': 5335,
#    u'delfzijl': 13335,
#    u'eemsmond': 8350,
#    u'groningen': 92675,
#    u'grootegast': 6210,
#    u'haren': 8720,
#    u'hoogezand-sappemeer': 17160,
#    u'leek': 9570,
#    u'loppersum': 5315,
#    u'marum': 5390,
#    u'menterwolde': 6335,
#    u'oldambt': 19460,
#    u'pekela': 6550,
#    u'slochteren': 7950,
#    u'stadskanaal': 16510,
#    u'ten boer': 3725,
#    u'veendam': 13910,
#    u'vlagtwedde': 8060,
#    u'winsum': 7030,
#    u'zuidhorn': 9240},
#   'Limburg': {u'beek': 8065,
#    u'beesel': 6995,
#    u'bergen (l.)': 6700,
#    u'brunssum': 14330,
#    u'echt-susteren': 16230,
#    u'eijsden': 5710,
#    u'gennep': 8755,
#    u'gulpen-wittem': 7355,
#    u'heerlen': 44060,
#    u'horst aan de maas': 20985,
#    u'kerkrade': 23725,
#    u'landgraaf': 18920,
#    u'leudal': 18570,
#    u'maasgouw': 12085,
#    u'maastricht': 56955,
#    u'margraten': 6765,
#    u'meerssen': 9615,
#    u'mook en middelaar': 4020,
#    u'nederweert': 8415,
#    u'nuth': 7700,
#    u'onderbanken': 4025,
#    u'peel en maas': 21830,
#    u'roerdalen': 10650,
#    u'roermond': 27185,
#    u'schinnen': 6795,
#    u'simpelveld': 5435,
#    u'sittard-geleen': 46785,
#    u'stein': 12805,
#    u'vaals': 4900,
#    u'valkenburg aan de geul': 8430,
#    u'venlo': 49715,
#    u'venray': 21515,
#    u'voerendaal': 6340,
#    u'weert': 24230},
#   'Noord-Brabant': {u"'s-hertogenbosch": 68630,
#    u'aalburg': 6310,
#    u'alphen-chaam': 4785,
#    u'asten': 8370,
#    u'baarle-nassau': 3435,
#    u'bergeijk': 9150,
#    u'bergen op zoom': 32515,
#    u'bernheze': 14930,
#    u'best': 14455,
#    u'bladel': 9735,
#    u'boekel': 4970,
#    u'boxmeer': 14315,
#    u'boxtel': 15025,
#    u'breda': 84445,
#    u'cranendonck': 10260,
#    u'cuijk': 12235,
#    u'deurne': 15825,
#    u'dongen': 12435,
#    u'drimmelen': 13290,
#    u'eersel': 9255,
#    u'eindhoven': 108495,
#    u'etten-leur': 20545,
#    u'geertruidenberg': 10490,
#    u'geldrop-mierlo': 18870,
#    u'gemert-bakel': 14575,
#    u'gilze en rijen': 13225,
#    u'goirle': 11285,
#    u'grave': 6640,
#    u'haaren': 6970,
#    u'halderberge': 14595,
#    u'heeze-leende': 7700,
#    u'helmond': 44255,
#    u'heusden': 21580,
#    u'hilvarenbeek': 7575,
#    u'laarbeek': 10910,
#    u'landerd': 7630,
#    u'lith': 3385,
#    u'loon op zand': 11380,
#    u'maasdonk': 5640,
#    u'mill en sint hubert': 5625,
#    u'moerdijk': 18220,
#    u'nuenen, gerwen en nederwetten': 11080,
#    u'oirschot': 9040,
#    u'oisterwijk': 12735,
#    u'oosterhout': 26620,
#    u'oss': 38630,
#    u'reusel-de mierden': 6415,
#    u'roosendaal': 38275,
#    u'rucphen': 11265,
#    u'schijndel': 11475,
#    u'sint anthonis': 6070,
#    u'sint-michielsgestel': 14105,
#    u'sint-oedenrode': 8810,
#    u'someren': 9255,
#    u'son en breugel': 7655,
#    u'steenbergen': 11680,
#    u'tilburg': 101695,
#    u'uden': 20185,
#    u'valkenswaard': 15175,
#    u'veghel': 18720,
#    u'veldhoven': 21550,
#    u'vught': 12595,
#    u'waalre': 8155,
#    u'waalwijk': 22750,
#    u'werkendam': 13210,
#    u'woensdrecht': 10865,
#    u'woudrichem': 7235,
#    u'zundert': 10710},
#   'Noord-Holland': {u'aalsmeer': 14480,
#    u'alkmaar': 46225,
#    u'amstelveen': 38435,
#    u'amsterdam': 378195,
#    u'andijk': 3370,
#    u'anna paulowna': 7220,
#    u'beemster': 4295,
#    u'bergen (nh.)': 15020,
#    u'beverwijk': 19210,
#    u'blaricum': 4325,
#    u'bloemendaal': 10405,
#    u'bussum': 15220,
#    u'castricum': 16935,
#    u'den helder': 28510,
#    u'diemen': 11945,
#    u'drechterland': 9785,
#    u'edam-volendam': 14300,
#    u'enkhuizen': 9080,
#    u'graft-de rijp': 3255,
#    u'haarlem': 72745,
#    u'haarlemmerliede en spaarnwoude': 2665,
#    u'haarlemmermeer': 71000,
#    u'harenkarspel': 8250,
#    u'heemskerk': 19040,
#    u'heemstede': 12210,
#    u'heerhugowaard': 25795,
#    u'heiloo': 11110,
#    u'hilversum': 41115,
#    u'hoorn': 34585,
#    u'huizen': 20335,
#    u'koggenland': 11075,
#    u'landsmeer': 4915,
#    u'langedijk': 13435,
#    u'laren': 5370,
#    u'medemblik': 13860,
#    u'muiden': 3170,
#    u'naarden': 8190,
#    u'niedorp': 6160,
#    u'oostzaan': 4450,
#    u'opmeer': 5750,
#    u'ouder-amstel': 6375,
#    u'purmerend': 38665,
#    u'schagen': 9120,
#    u'schermer': 2750,
#    u'stede broec': 10755,
#    u'texel': 6830,
#    u'uitgeest': 6365,
#    u'uithoorn': 13820,
#    u'velsen': 33305,
#    u'waterland': 8530,
#    u'weesp': 8560,
#    u'wervershoof': 4460,
#    u'wieringen': 4360,
#    u'wieringermeer': 6350,
#    u'wijdemeren': 11440,
#    u'wormerland': 7925,
#    u'zaanstad': 71695,
#    u'zandvoort': 7965,
#    u'zeevang': 3155,
#    u'zijpe': 5830},
#   'Overijssel': {u'almelo': 36060,
#    u'borne': 10680,
#    u'dalfsen': 13850,
#    u'deventer': 48600,
#    u'dinkelland': 13230,
#    u'enschede': 79840,
#    u'haaksbergen': 12295,
#    u'hardenberg': 29850,
#    u'hellendoorn': 17900,
#    u'hengelo': 40105,
#    u'hof van twente': 17600,
#    u'kampen': 24835,
#    u'losser': 11355,
#    u'oldenzaal': 15930,
#    u'olst-wijhe': 8865,
#    u'ommen': 8720,
#    u'raalte': 18435,
#    u'rijssen-holten': 18445,
#    u'staphorst': 8295,
#    u'steenwijkerland': 21595,
#    u'tubbergen': 10710,
#    u'twenterand': 16995,
#    u'wierden': 11755,
#    u'zwartewaterland': 11080,
#    u'zwolle': 57935},
#   'Utrecht': {u'abcoude': 4295,
#    u'amersfoort': 71085,
#    u'baarn': 11660,
#    u'breukelen': 7225,
#    u'bunnik': 7130,
#    u'bunschoten': 10030,
#    u'de bilt': 19935,
#    u'de ronde venen': 17140,
#    u'eemnes': 4380,
#    u'houten': 23515,
#    u'ijsselstein': 16700,
#    u'leusden': 14170,
#    u'loenen': 4165,
#    u'lopik': 7205,
#    u'maarssen': 19365,
#    u'montfoort': 6750,
#    u'nieuwegein': 30205,
#    u'oudewater': 4855,
#    u'renswoude': 2285,
#    u'rhenen': 9330,
#    u'soest': 22210,
#    u'utrecht': 148550,
#    u'utrechtse heuvelrug': 23595,
#    u'veenendaal': 30490,
#    u'vianen': 9670,
#    u'wijk bij duurstede': 11460,
#    u'woerden': 24380,
#    u'woudenberg': 5970,
#    u'zeist': 29030},
#   'Zeeland': {u'borsele': 11465,
#    u'goes': 17815,
#    u'hulst': 13875,
#    u'kapelle': 6160,
#    u'middelburg': 23430,
#    u'noord-beveland': 3690,
#    u'reimerswaal': 10740,
#    u'schouwen-duiveland': 16820,
#    u'sluis': 11815,
#    u'terneuzen': 27290,
#    u'tholen': 12760,
#    u'veere': 11000,
#    u'vlissingen': 22320},
#   'Zuid-Holland': {u"'s-gravenhage": 240695,
#    u'alblasserdam': 9290,
#    u'albrandswaard': 12050,
#    u'alphen aan den rijn': 35765,
#    u'barendrecht': 22955,
#    u'bergambacht': 4805,
#    u'bernisse': 6265,
#    u'binnenmaas': 14350,
#    u'bodegraven': 9760,
#    u'boskoop': 7545,
#    u'brielle': 7865,
#    u'capelle aan den ijssel': 31560,
#    u'cromstrijen': 6375,
#    u'delft': 50850,
#    u'dirksland': 4195,
#    u'dordrecht': 58315,
#    u'giessenlanden': 7350,
#    u'goedereede': 5665,
#    u'gorinchem': 17010,
#    u'gouda': 34760,
#    u'graafstroom': 5035,
#    u'hardinxveld-giessendam': 8690,
#    u'hellevoetsluis': 19750,
#    u'hendrik-ido-ambacht': 13195,
#    u'hillegom': 10115,
#    u'kaag en braassem': 13000,
#    u'katwijk': 30780,
#    u'korendijk': 5445,
#    u'krimpen aan den ijssel': 14040,
#    u'lansingerland': 26235,
#    u'leerdam': 10165,
#    u'leiden': 57075,
#    u'leiderdorp': 12785,
#    u'leidschendam-voorburg': 34465,
#    u'liesveld': 4915,
#    u'lisse': 10990,
#    u'maassluis': 15515,
#    u'middelharnis': 8805,
#    u'midden-delfland': 9095,
#    u'nederlek': 6935,
#    u'nieuw-lekkerland': 4865,
#    u'nieuwkoop': 13640,
#    u'noordwijk': 12760,
#    u'noordwijkerhout': 7850,
#    u'oegstgeest': 10885,
#    u'oostflakkee': 5210,
#    u'oud-beijerland': 11555,
#    u'ouderkerk': 4065,
#    u'papendrecht': 15610,
#    u'pijnacker-nootdorp': 24035,
#    u'reeuwijk': 6535,
#    u'ridderkerk': 21725,
#    u'rijnwoude': 9375,
#    u'rijswijk': 22015,
#    u'rotterdam': 291630,
#    u'rozenburg': 6235,
#    u'schiedam': 37120,
#    u'schoonhoven': 5895,
#    u'sliedrecht': 11785,
#    u'spijkenisse': 35500,
#    u'strijen': 4460,
#    u'teylingen': 17810,
#    u'vlaardingen': 34400,
#    u'vlist': 4880,
#    u'voorschoten': 11245,
#    u'waddinxveen': 12615,
#    u'wassenaar': 12320,
#    u'westland': 49710,
#    u'westvoorne': 7000,
#    u'zederik': 6625,
#    u'zoetermeer': 59545,
#    u'zoeterwoude': 4030,
#    u'zuidplas': 20085,
#    u'zwijndrecht': 21615}},
#  '2011': {'Drenthe': {u'aa en hunze': 12840,
#    u'assen': 32830,
#    u'borger-odoorn': 12950,
#    u'coevorden': 17970,
#    u'de wolden': 11840,
#    u'emmen': 54040,
#    u'hoogeveen': 27205,
#    u'meppel': 15835,
#    u'midden-drenthe': 16750,
#    u'noordenveld': 15220,
#    u'tynaarlo': 15940,
#    u'westerveld': 9655},
#   'Flevoland': {u'almere': 94640,
#    u'dronten': 20305,
#    u'lelystad': 37520,
#    u'noordoostpolder': 23445,
#    u'urk': 9435,
#    u'zeewolde': 10720},
#   'Friesland': {u'achtkarspelen': 14270,
#    u'ameland': 1750,
#    u'boarnsterhim': 9700,
#    u'dantumadiel': 9660,
#    u'dongeradeel': 12190,
#    u'ferwerderadiel': 4540,
#    u'franekeradeel': 10475,
#    u'gaasterl\xe2n-sleat': 5170,
#    u'harlingen': 7955,
#    u'heerenveen': 21350,
#    u'het bildt': 5615,
#    u'kollumerland en nieuwkruisland': 6635,
#    u'leeuwarden': 46405,
#    u'leeuwarderadeel': 5225,
#    u'lemsterland': 6920,
#    u'littenseradiel': 5600,
#    u'menameradiel': 6980,
#    u'ooststellingwerf': 13025,
#    u'opsterland': 14995,
#    u'schiermonnikoog': 470,
#    u'skarsterl\xe2n': 13730,
#    u'smallingerland': 27490,
#    u's\xfadwest-frysl\xe2n': 41230,
#    u'terschelling': 2485,
#    u'tytsjerksteradiel': 16045,
#    u'vlieland': 575,
#    u'weststellingwerf': 12945},
#   'Gelderland': {u'aalten': 13755,
#    u'apeldoorn': 77090,
#    u'arnhem': 73505,
#    u'barneveld': 26365,
#    u'berkelland': 22545,
#    u'beuningen': 12740,
#    u'bronckhorst': 18705,
#    u'brummen': 10465,
#    u'buren': 13005,
#    u'culemborg': 13675,
#    u'doesburg': 5695,
#    u'doetinchem': 27730,
#    u'druten': 9005,
#    u'duiven': 12535,
#    u'ede': 53145,
#    u'elburg': 11010,
#    u'epe': 16190,
#    u'ermelo': 12860,
#    u'geldermalsen': 12995,
#    u'groesbeek': 9220,
#    u'harderwijk': 22115,
#    u'hattem': 5755,
#    u'heerde': 9025,
#    u'heumen': 8180,
#    u'lingewaal': 5440,
#    u'lingewaard': 22585,
#    u'lochem': 16370,
#    u'maasdriel': 12095,
#    u'millingen aan de rijn': 2965,
#    u'montferland': 17420,
#    u'neder-betuwe': 11260,
#    u'neerijnen': 5980,
#    u'nijkerk': 19790,
#    u'nijmegen': 78580,
#    u'nunspeet': 13170,
#    u'oldebroek': 11450,
#    u'oost gelre': 15335,
#    u'oude ijsselstreek': 19920,
#    u'overbetuwe': 22855,
#    u'putten': 11770,
#    u'renkum': 15210,
#    u'rheden': 21325,
#    u'rijnwaarden': 5465,
#    u'rozendaal': 755,
#    u'scherpenzeel': 4630,
#    u'tiel': 20445,
#    u'ubbergen': 4605,
#    u'voorst': 11835,
#    u'wageningen': 17590,
#    u'west maas en waal': 9150,
#    u'westervoort': 7600,
#    u'wijchen': 19965,
#    u'winterswijk': 14410,
#    u'zaltbommel': 13300,
#    u'zevenaar': 15855,
#    u'zutphen': 22965},
#   'Groningen': {u'appingedam': 5870,
#    u'bedum': 5280,
#    u'bellingwedde': 4740,
#    u'de marne': 5335,
#    u'delfzijl': 13295,
#    u'eemsmond': 8325,
#    u'groningen': 94065,
#    u'grootegast': 6255,
#    u'haren': 8735,
#    u'hoogezand-sappemeer': 17150,
#    u'leek': 9565,
#    u'loppersum': 5340,
#    u'marum': 5395,
#    u'menterwolde': 6305,
#    u'oldambt': 19455,
#    u'pekela': 6495,
#    u'slochteren': 7930,
#    u'stadskanaal': 16350,
#    u'ten boer': 3740,
#    u'veendam': 13885,
#    u'vlagtwedde': 8125,
#    u'winsum': 7005,
#    u'zuidhorn': 9280},
#   'Limburg': {u'beek': 8055,
#    u'beesel': 6985,
#    u'bergen (l.)': 6680,
#    u'brunssum': 14310,
#    u'echt-susteren': 16195,
#    u'eijsden-margraten': 12485,
#    u'gennep': 8905,
#    u'gulpen-wittem': 7310,
#    u'heerlen': 44120,
#    u'horst aan de maas': 21130,
#    u'kerkrade': 23615,
#    u'landgraaf': 18760,
#    u'leudal': 18485,
#    u'maasgouw': 12135,
#    u'maastricht': 57540,
#    u'meerssen': 9575,
#    u'mook en middelaar': 3965,
#    u'nederweert': 8415,
#    u'nuth': 7655,
#    u'onderbanken': 3975,
#    u'peel en maas': 21895,
#    u'roerdalen': 10625,
#    u'roermond': 27415,
#    u'schinnen': 6765,
#    u'simpelveld': 5440,
#    u'sittard-geleen': 46570,
#    u'stein': 12820,
#    u'vaals': 4820,
#    u'valkenburg aan de geul': 8440,
#    u'venlo': 49410,
#    u'venray': 21520,
#    u'voerendaal': 6300,
#    u'weert': 24315},
#   'Noord-Brabant': {u"'s-hertogenbosch": 69200,
#    u'aalburg': 6375,
#    u'alphen-chaam': 4800,
#    u'asten': 8345,
#    u'baarle-nassau': 3425,
#    u'bergeijk': 9175,
#    u'bergen op zoom': 32640,
#    u'bernheze': 14960,
#    u'best': 14385,
#    u'bladel': 9880,
#    u'boekel': 5040,
#    u'boxmeer': 14310,
#    u'boxtel': 15015,
#    u'breda': 85005,
#    u'cranendonck': 10290,
#    u'cuijk': 12310,
#    u'deurne': 15925,
#    u'dongen': 12480,
#    u'drimmelen': 13225,
#    u'eersel': 9235,
#    u'eindhoven': 109975,
#    u'etten-leur': 20690,
#    u'geertruidenberg': 10585,
#    u'geldrop-mierlo': 19000,
#    u'gemert-bakel': 14625,
#    u'gilze en rijen': 13040,
#    u'goirle': 11305,
#    u'grave': 6720,
#    u'haaren': 6955,
#    u'halderberge': 14585,
#    u'heeze-leende': 7720,
#    u'helmond': 44400,
#    u'heusden': 21600,
#    u'hilvarenbeek': 7605,
#    u'laarbeek': 10890,
#    u'landerd': 7670,
#    u'loon op zand': 11340,
#    u'maasdonk': 5640,
#    u'mill en sint hubert': 5600,
#    u'moerdijk': 18250,
#    u'nuenen, gerwen en nederwetten': 11080,
#    u'oirschot': 9060,
#    u'oisterwijk': 12630,
#    u'oosterhout': 26600,
#    u'oss': 42100,
#    u'reusel-de mierden': 6415,
#    u'roosendaal': 38300,
#    u'rucphen': 11205,
#    u'schijndel': 11505,
#    u'sint anthonis': 6050,
#    u'sint-michielsgestel': 14115,
#    u'sint-oedenrode': 8890,
#    u'someren': 9290,
#    u'son en breugel': 7740,
#    u'steenbergen': 11680,
#    u'tilburg': 102365,
#    u'uden': 20225,
#    u'valkenswaard': 15125,
#    u'veghel': 18845,
#    u'veldhoven': 21750,
#    u'vught': 12750,
#    u'waalre': 8125,
#    u'waalwijk': 22995,
#    u'werkendam': 13170,
#    u'woensdrecht': 10900,
#    u'woudrichem': 7225,
#    u'zundert': 10805},
#   'Noord-Holland': {u'aalsmeer': 14955,
#    u'alkmaar': 46295,
#    u'amstelveen': 38920,
#    u'amsterdam': 383800,
#    u'anna paulowna': 7215,
#    u'beemster': 4295,
#    u'bergen (nh.)': 15000,
#    u'beverwijk': 19405,
#    u'blaricum': 4330,
#    u'bloemendaal': 10455,
#    u'bussum': 15355,
#    u'castricum': 16910,
#    u'den helder': 28385,
#    u'diemen': 12090,
#    u'drechterland': 9815,
#    u'edam-volendam': 14320,
#    u'enkhuizen': 9095,
#    u'graft-de rijp': 3255,
#    u'haarlem': 73260,
#    u'haarlemmerliede en spaarnwoude': 2685,
#    u'haarlemmermeer': 71310,
#    u'harenkarspel': 8290,
#    u'heemskerk': 19235,
#    u'heemstede': 12325,
#    u'heerhugowaard': 26160,
#    u'heiloo': 11135,
#    u'hilversum': 41320,
#    u'hoorn': 34905,
#    u'huizen': 20235,
#    u'koggenland': 11110,
#    u'landsmeer': 4925,
#    u'langedijk': 13465,
#    u'laren': 5420,
#    u'medemblik': 21820,
#    u'muiden': 3170,
#    u'naarden': 8240,
#    u'niedorp': 6190,
#    u'oostzaan': 4455,
#    u'opmeer': 5755,
#    u'ouder-amstel': 6400,
#    u'purmerend': 38685,
#    u'schagen': 9100,
#    u'schermer': 2725,
#    u'stede broec': 10810,
#    u'texel': 6805,
#    u'uitgeest': 6455,
#    u'uithoorn': 13855,
#    u'velsen': 33295,
#    u'waterland': 8560,
#    u'weesp': 8710,
#    u'wieringen': 4350,
#    u'wieringermeer': 6370,
#    u'wijdemeren': 11395,
#    u'wormerland': 7905,
#    u'zaanstad': 72545,
#    u'zandvoort': 8010,
#    u'zeevang': 3175,
#    u'zijpe': 5850},
#   'Overijssel': {u'almelo': 35990,
#    u'borne': 10795,
#    u'dalfsen': 13885,
#    u'deventer': 48630,
#    u'dinkelland': 13225,
#    u'enschede': 80120,
#    u'haaksbergen': 12260,
#    u'hardenberg': 30015,
#    u'hellendoorn': 17840,
#    u'hengelo': 40115,
#    u'hof van twente': 17650,
#    u'kampen': 25035,
#    u'losser': 11375,
#    u'oldenzaal': 16010,
#    u'olst-wijhe': 8840,
#    u'ommen': 8670,
#    u'raalte': 18345,
#    u'rijssen-holten': 18615,
#    u'staphorst': 8315,
#    u'steenwijkerland': 21670,
#    u'tubbergen': 10745,
#    u'twenterand': 17070,
#    u'wierden': 11835,
#    u'zwartewaterland': 11150,
#    u'zwolle': 58695},
#   'Utrecht': {u'amersfoort': 71980,
#    u'baarn': 11715,
#    u'bunnik': 7130,
#    u'bunschoten': 10080,
#    u'de bilt': 19955,
#    u'de ronde venen': 21355,
#    u'eemnes': 4370,
#    u'houten': 23680,
#    u'ijsselstein': 16765,
#    u'leusden': 14000,
#    u'lopik': 7165,
#    u'montfoort': 6765,
#    u'nieuwegein': 30195,
#    u'oudewater': 4840,
#    u'renswoude': 2360,
#    u'rhenen': 9390,
#    u'soest': 22120,
#    u'stichtse vecht': 30875,
#    u'utrecht': 150570,
#    u'utrechtse heuvelrug': 23540,
#    u'veenendaal': 30565,
#    u'vianen': 9705,
#    u'wijk bij duurstede': 11445,
#    u'woerden': 24625,
#    u'woudenberg': 6005,
#    u'zeist': 29325},
#   'Zeeland': {u'borsele': 11505,
#    u'goes': 17885,
#    u'hulst': 13810,
#    u'kapelle': 6140,
#    u'middelburg': 23385,
#    u'noord-beveland': 3740,
#    u'reimerswaal': 10825,
#    u'schouwen-duiveland': 16895,
#    u'sluis': 11770,
#    u'terneuzen': 27295,
#    u'tholen': 12785,
#    u'veere': 10955,
#    u'vlissingen': 22190},
#   'Zuid-Holland': {u"'s-gravenhage": 244040,
#    u'alblasserdam': 9395,
#    u'albrandswaard': 12250,
#    u'alphen aan den rijn': 35880,
#    u'barendrecht': 23145,
#    u'bergambacht': 4845,
#    u'bernisse': 6235,
#    u'binnenmaas': 14370,
#    u'bodegraven-reeuwijk': 16380,
#    u'boskoop': 7510,
#    u'brielle': 7960,
#    u'capelle aan den ijssel': 31960,
#    u'cromstrijen': 6345,
#    u'delft': 51650,
#    u'dirksland': 4190,
#    u'dordrecht': 58525,
#    u'giessenlanden': 7325,
#    u'goedereede': 5635,
#    u'gorinchem': 17115,
#    u'gouda': 34740,
#    u'graafstroom': 5035,
#    u'hardinxveld-giessendam': 8725,
#    u'hellevoetsluis': 19845,
#    u'hendrik-ido-ambacht': 13515,
#    u'hillegom': 10175,
#    u'kaag en braassem': 13035,
#    u'katwijk': 30895,
#    u'korendijk': 5445,
#    u'krimpen aan den ijssel': 13925,
#    u'lansingerland': 26925,
#    u'leerdam': 10150,
#    u'leiden': 57525,
#    u'leiderdorp': 12870,
#    u'leidschendam-voorburg': 34445,
#    u'liesveld': 4900,
#    u'lisse': 11160,
#    u'maassluis': 15660,
#    u'middelharnis': 8845,
#    u'midden-delfland': 9190,
#    u'nederlek': 6915,
#    u'nieuw-lekkerland': 4880,
#    u'nieuwkoop': 13655,
#    u'noordwijk': 12810,
#    u'noordwijkerhout': 7880,
#    u'oegstgeest': 10935,
#    u'oostflakkee': 5215,
#    u'oud-beijerland': 11540,
#    u'ouderkerk': 4040,
#    u'papendrecht': 15645,
#    u'pijnacker-nootdorp': 24660,
#    u'ridderkerk': 21755,
#    u'rijnwoude': 9325,
#    u'rijswijk': 22030,
#    u'rotterdam': 300320,
#    u'schiedam': 37250,
#    u'schoonhoven': 5865,
#    u'sliedrecht': 11810,
#    u'spijkenisse': 35440,
#    u'strijen': 4430,
#    u'teylingen': 17875,
#    u'vlaardingen': 34800,
#    u'vlist': 4885,
#    u'voorschoten': 11455,
#    u'waddinxveen': 12610,
#    u'wassenaar': 12295,
#    u'westland': 49690,
#    u'westvoorne': 6945,
#    u'zederik': 6630,
#    u'zoetermeer': 59735,
#    u'zoeterwoude': 4045,
#    u'zuidplas': 20120,
#    u'zwijndrecht': 21620}},
#  '2012': {'Drenthe': {u'aa en hunze': 12835,
#    u'assen': 32930,
#    u'borger-odoorn': 12895,
#    u'coevorden': 17915,
#    u'de wolden': 11900,
#    u'emmen': 53915,
#    u'hoogeveen': 27280,
#    u'meppel': 15920,
#    u'midden-drenthe': 16740,
#    u'noordenveld': 15340,
#    u'tynaarlo': 15910,
#    u'westerveld': 9555},
#   'Flevoland': {u'almere': 95875,
#    u'dronten': 20525,
#    u'lelystad': 37545,
#    u'noordoostpolder': 23450,
#    u'urk': 9590,
#    u'zeewolde': 10800},
#   'Friesland': {u'achtkarspelen': 14265,
#    u'ameland': 1755,
#    u'boarnsterhim': 9720,
#    u'dantumadiel': 9645,
#    u'dongeradeel': 12190,
#    u'ferwerderadiel': 4530,
#    u'franekeradeel': 10300,
#    u'gaasterl\xe2n-sleat': 5150,
#    u'harlingen': 7955,
#    u'heerenveen': 21400,
#    u'het bildt': 5535,
#    u'kollumerland en nieuwkruisland': 6630,
#    u'leeuwarden': 46725,
#    u'leeuwarderadeel': 5210,
#    u'lemsterland': 6900,
#    u'littenseradiel': 5545,
#    u'menameradiel': 7010,
#    u'ooststellingwerf': 12940,
#    u'opsterland': 14945,
#    u'schiermonnikoog': 465,
#    u'skarsterl\xe2n': 13795,
#    u'smallingerland': 27570,
#    u's\xfadwest-frysl\xe2n': 41290,
#    u'terschelling': 2510,
#    u'tytsjerksteradiel': 16035,
#    u'vlieland': 555,
#    u'weststellingwerf': 12920},
#   'Gelderland': {u'aalten': 13685,
#    u'apeldoorn': 77525,
#    u'arnhem': 74065,
#    u'barneveld': 26615,
#    u'berkelland': 22620,
#    u'beuningen': 12685,
#    u'bronckhorst': 18600,
#    u'brummen': 10520,
#    u'buren': 12985,
#    u'culemborg': 13685,
#    u'doesburg': 5655,
#    u'doetinchem': 27855,
#    u'druten': 9035,
#    u'duiven': 12515,
#    u'ede': 53370,
#    u'elburg': 11105,
#    u'epe': 16045,
#    u'ermelo': 12865,
#    u'geldermalsen': 13050,
#    u'groesbeek': 9255,
#    u'harderwijk': 22375,
#    u'hattem': 5785,
#    u'heerde': 9000,
#    u'heumen': 8130,
#    u'lingewaal': 5440,
#    u'lingewaard': 22705,
#    u'lochem': 16320,
#    u'maasdriel': 12120,
#    u'millingen aan de rijn': 2955,
#    u'montferland': 17470,
#    u'neder-betuwe': 11225,
#    u'neerijnen': 6000,
#    u'nijkerk': 19970,
#    u'nijmegen': 79080,
#    u'nunspeet': 13125,
#    u'oldebroek': 11455,
#    u'oost gelre': 15295,
#    u'oude ijsselstreek': 19890,
#    u'overbetuwe': 22995,
#    u'putten': 11835,
#    u'renkum': 15275,
#    u'rheden': 21215,
#    u'rijnwaarden': 5460,
#    u'rozendaal': 750,
#    u'scherpenzeel': 4640,
#    u'tiel': 20620,
#    u'ubbergen': 4625,
#    u'voorst': 11845,
#    u'wageningen': 17765,
#    u'west maas en waal': 9130,
#    u'westervoort': 7575,
#    u'wijchen': 20095,
#    u'winterswijk': 14385,
#    u'zaltbommel': 13400,
#    u'zevenaar': 15960,
#    u'zutphen': 23025},
#   'Groningen': {u'appingedam': 5820,
#    u'bedum': 5280,
#    u'bellingwedde': 4645,
#    u'de marne': 5305,
#    u'delfzijl': 13155,
#    u'eemsmond': 8255,
#    u'groningen': 95630,
#    u'grootegast': 6280,
#    u'haren': 8730,
#    u'hoogezand-sappemeer': 17160,
#    u'leek': 9660,
#    u'loppersum': 5285,
#    u'marum': 5340,
#    u'menterwolde': 6295,
#    u'oldambt': 19330,
#    u'pekela': 6450,
#    u'slochteren': 7910,
#    u'stadskanaal': 16290,
#    u'ten boer': 3745,
#    u'veendam': 13810,
#    u'vlagtwedde': 8110,
#    u'winsum': 6955,
#    u'zuidhorn': 9305},
#   'Limburg': {u'beek': 8000,
#    u'beesel': 6920,
#    u'bergen (l.)': 6660,
#    u'brunssum': 14235,
#    u'echt-susteren': 16095,
#    u'eijsden-margraten': 12500,
#    u'gennep': 8870,
#    u'gulpen-wittem': 7275,
#    u'heerlen': 44005,
#    u'horst aan de maas': 21120,
#    u'kerkrade': 23540,
#    u'landgraaf': 18730,
#    u'leudal': 18445,
#    u'maasgouw': 12035,
#    u'maastricht': 58230,
#    u'meerssen': 9555,
#    u'mook en middelaar': 3920,
#    u'nederweert': 8445,
#    u'nuth': 7710,
#    u'onderbanken': 3950,
#    u'peel en maas': 21970,
#    u'roerdalen': 10565,
#    u'roermond': 27745,
#    u'schinnen': 6645,
#    u'simpelveld': 5430,
#    u'sittard-geleen': 46505,
#    u'stein': 12740,
#    u'vaals': 4805,
#    u'valkenburg aan de geul': 8375,
#    u'venlo': 49600,
#    u'venray': 21630,
#    u'voerendaal': 6315,
#    u'weert': 24345},
#   'Noord-Brabant': {u"'s-hertogenbosch": 69810,
#    u'aalburg': 6440,
#    u'alphen-chaam': 4825,
#    u'asten': 8410,
#    u'baarle-nassau': 3425,
#    u'bergeijk': 9185,
#    u'bergen op zoom': 32660,
#    u'bernheze': 15025,
#    u'best': 14355,
#    u'bladel': 9965,
#    u'boekel': 5095,
#    u'boxmeer': 14190,
#    u'boxtel': 14990,
#    u'breda': 85975,
#    u'cranendonck': 10340,
#    u'cuijk': 12330,
#    u'deurne': 16000,
#    u'dongen': 12500,
#    u'drimmelen': 13335,
#    u'eersel': 9220,
#    u'eindhoven': 110745,
#    u'etten-leur': 20805,
#    u'geertruidenberg': 10675,
#    u'geldrop-mierlo': 19125,
#    u'gemert-bakel': 14660,
#    u'gilze en rijen': 12885,
#    u'goirle': 11315,
#    u'grave': 6605,
#    u'haaren': 6960,
#    u'halderberge': 14565,
#    u'heeze-leende': 7755,
#    u'helmond': 44565,
#    u'heusden': 21555,
#    u'hilvarenbeek': 7600,
#    u'laarbeek': 10920,
#    u'landerd': 7700,
#    u'loon op zand': 11425,
#    u'maasdonk': 5645,
#    u'mill en sint hubert': 5540,
#    u'moerdijk': 18195,
#    u'nuenen, gerwen en nederwetten': 11185,
#    u'oirschot': 9050,
#    u'oisterwijk': 12700,
#    u'oosterhout': 26610,
#    u'oss': 42280,
#    u'reusel-de mierden': 6460,
#    u'roosendaal': 38245,
#    u'rucphen': 11170,
#    u'schijndel': 11525,
#    u'sint anthonis': 6060,
#    u'sint-michielsgestel': 14145,
#    u'sint-oedenrode': 8950,
#    u'someren': 9455,
#    u'son en breugel': 7815,
#    u'steenbergen': 11745,
#    u'tilburg': 103015,
#    u'uden': 20245,
#    u'valkenswaard': 15150,
#    u'veghel': 18880,
#    u'veldhoven': 21880,
#    u'vught': 12730,
#    u'waalre': 8145,
#    u'waalwijk': 23105,
#    u'werkendam': 13185,
#    u'woensdrecht': 10860,
#    u'woudrichem': 7215,
#    u'zundert': 10865},
#   'Noord-Holland': {u'aalsmeer': 15050,
#    u'alkmaar': 46425,
#    u'amstelveen': 39710,
#    u'amsterdam': 389005,
#    u'beemster': 4360,
#    u'bergen (nh.)': 14870,
#    u'beverwijk': 19720,
#    u'blaricum': 4370,
#    u'bloemendaal': 10495,
#    u'bussum': 15470,
#    u'castricum': 16855,
#    u'den helder': 28285,
#    u'diemen': 12045,
#    u'drechterland': 9795,
#    u'edam-volendam': 14370,
#    u'enkhuizen': 9130,
#    u'graft-de rijp': 3230,
#    u'haarlem': 73920,
#    u'haarlemmerliede en spaarnwoude': 2700,
#    u'haarlemmermeer': 71555,
#    u'harenkarspel': 8300,
#    u'heemskerk': 19245,
#    u'heemstede': 12350,
#    u'heerhugowaard': 26460,
#    u'heiloo': 11140,
#    u'hilversum': 41585,
#    u'hollands kroon': 24150,
#    u'hoorn': 35130,
#    u'huizen': 20225,
#    u'koggenland': 11235,
#    u'landsmeer': 4960,
#    u'langedijk': 13465,
#    u'laren': 5420,
#    u'medemblik': 21915,
#    u'muiden': 3125,
#    u'naarden': 8255,
#    u'oostzaan': 4450,
#    u'opmeer': 5770,
#    u'ouder-amstel': 6450,
#    u'purmerend': 38730,
#    u'schagen': 9105,
#    u'schermer': 2775,
#    u'stede broec': 10860,
#    u'texel': 6775,
#    u'uitgeest': 6470,
#    u'uithoorn': 13975,
#    u'velsen': 33290,
#    u'waterland': 8480,
#    u'weesp': 8730,
#    u'wijdemeren': 11415,
#    u'wormerland': 7895,
#    u'zaanstad': 73310,
#    u'zandvoort': 8000,
#    u'zeevang': 3165,
#    u'zijpe': 5850},
#   'Overijssel': {u'almelo': 36090,
#    u'borne': 10800,
#    u'dalfsen': 13935,
#    u'deventer': 48550,
#    u'dinkelland': 13245,
#    u'enschede': 80220,
#    u'haaksbergen': 12290,
#    u'hardenberg': 30105,
#    u'hellendoorn': 17885,
#    u'hengelo': 40290,
#    u'hof van twente': 17675,
#    u'kampen': 25205,
#    u'losser': 11395,
#    u'oldenzaal': 16075,
#    u'olst-wijhe': 8920,
#    u'ommen': 8700,
#    u'raalte': 18330,
#    u'rijssen-holten': 18665,
#    u'staphorst': 8325,
#    u'steenwijkerland': 21710,
#    u'tubbergen': 10780,
#    u'twenterand': 17195,
#    u'wierden': 11925,
#    u'zwartewaterland': 11175,
#    u'zwolle': 59280},
#   'Utrecht': {u'amersfoort': 72850,
#    u'baarn': 11710,
#    u'bunnik': 7140,
#    u'bunschoten': 10120,
#    u'de bilt': 19980,
#    u'de ronde venen': 21355,
#    u'eemnes': 4365,
#    u'houten': 23915,
#    u'ijsselstein': 16720,
#    u'leusden': 14155,
#    u'lopik': 7155,
#    u'montfoort': 6810,
#    u'nieuwegein': 30060,
#    u'oudewater': 4850,
#    u'renswoude': 2395,
#    u'rhenen': 9440,
#    u'soest': 22210,
#    u'stichtse vecht': 31025,
#    u'utrecht': 153280,
#    u'utrechtse heuvelrug': 23300,
#    u'veenendaal': 30855,
#    u'vianen': 9680,
#    u'wijk bij duurstede': 11395,
#    u'woerden': 24730,
#    u'woudenberg': 6025,
#    u'zeist': 29510},
#   'Zeeland': {u'borsele': 11490,
#    u'goes': 18045,
#    u'hulst': 13780,
#    u'kapelle': 6165,
#    u'middelburg': 23240,
#    u'noord-beveland': 3765,
#    u'reimerswaal': 10900,
#    u'schouwen-duiveland': 16865,
#    u'sluis': 11730,
#    u'terneuzen': 27250,
#    u'tholen': 12795,
#    u'veere': 10995,
#    u'vlissingen': 22155},
#   'Zuid-Holland': {u"'s-gravenhage": 247865,
#    u'alblasserdam': 9495,
#    u'albrandswaard': 12390,
#    u'alphen aan den rijn': 35960,
#    u'barendrecht': 23230,
#    u'bergambacht': 4890,
#    u'bernisse': 6245,
#    u'binnenmaas': 14335,
#    u'bodegraven-reeuwijk': 16440,
#    u'boskoop': 7525,
#    u'brielle': 7915,
#    u'capelle aan den ijssel': 31925,
#    u'cromstrijen': 6345,
#    u'delft': 52300,
#    u'dirksland': 4235,
#    u'dordrecht': 58555,
#    u'giessenlanden': 7380,
#    u'goedereede': 5625,
#    u'gorinchem': 17250,
#    u'gouda': 34855,
#    u'graafstroom': 5010,
#    u'hardinxveld-giessendam': 8770,
#    u'hellevoetsluis': 19720,
#    u'hendrik-ido-ambacht': 13850,
#    u'hillegom': 10305,
#    u'kaag en braassem': 13060,
#    u'katwijk': 31020,
#    u'korendijk': 5400,
#    u'krimpen aan den ijssel': 13950,
#    u'lansingerland': 27525,
#    u'leerdam': 10155,
#    u'leiden': 57850,
#    u'leiderdorp': 12885,
#    u'leidschendam-voorburg': 34620,
#    u'liesveld': 4915,
#    u'lisse': 11085,
#    u'maassluis': 15605,
#    u'middelharnis': 8855,
#    u'midden-delfland': 9235,
#    u'nederlek': 6895,
#    u'nieuw-lekkerland': 4885,
#    u'nieuwkoop': 13650,
#    u'noordwijk': 12835,
#    u'noordwijkerhout': 7890,
#    u'oegstgeest': 10950,
#    u'oostflakkee': 5205,
#    u'oud-beijerland': 11505,
#    u'ouderkerk': 3975,
#    u'papendrecht': 15750,
#    u'pijnacker-nootdorp': 25025,
#    u'ridderkerk': 21865,
#    u'rijnwoude': 9370,
#    u'rijswijk': 22180,
#    u'rotterdam': 303770,
#    u'schiedam': 37490,
#    u'schoonhoven': 5830,
#    u'sliedrecht': 11895,
#    u'spijkenisse': 35370,
#    u'strijen': 4420,
#    u'teylingen': 17800,
#    u'vlaardingen': 34710,
#    u'vlist': 4865,
#    u'voorschoten': 11730,
#    u'waddinxveen': 12600,
#    u'wassenaar': 12200,
#    u'westland': 50800,
#    u'westvoorne': 6905,
#    u'zederik': 6680,
#    u'zoetermeer': 59955,
#    u'zoeterwoude': 4040,
#    u'zuidplas': 20180,
#    u'zwijndrecht': 21640}},
#  '2013': {'Drenthe': {u'aa en hunze': 12685,
#    u'assen': 33010,
#    u'borger-odoorn': 12835,
#    u'coevorden': 17810,
#    u'de wolden': 11915,
#    u'emmen': 53660,
#    u'hoogeveen': 27300,
#    u'meppel': 16020,
#    u'midden-drenthe': 16665,
#    u'noordenveld': 15395,
#    u'tynaarlo': 15935,
#    u'westerveld': 9520},
#   'Flevoland': {u'almere': 96925,
#    u'dronten': 20625,
#    u'lelystad': 37825,
#    u'noordoostpolder': 23410,
#    u'urk': 9750,
#    u'zeewolde': 10775},
#   'Friesland': {u'achtkarspelen': 14280,
#    u'ameland': 1750,
#    u'boarnsterhim': 9780,
#    u'dantumadiel': 9585,
#    u'dongeradeel': 12140,
#    u'ferwerderadiel': 4525,
#    u'franekeradeel': 10270,
#    u'gaasterl\xe2n-sleat': 5155,
#    u'harlingen': 7970,
#    u'heerenveen': 21355,
#    u'het bildt': 5435,
#    u'kollumerland en nieuwkruisland': 6600,
#    u'leeuwarden': 47115,
#    u'leeuwarderadeel': 5185,
#    u'lemsterland': 6890,
#    u'littenseradiel': 5565,
#    u'menameradiel': 7010,
#    u'ooststellingwerf': 12930,
#    u'opsterland': 14935,
#    u'schiermonnikoog': 485,
#    u'skarsterl\xe2n': 13725,
#    u'smallingerland': 27600,
#    u's\xfadwest-frysl\xe2n': 41235,
#    u'terschelling': 2535,
#    u'tytsjerksteradiel': 15960,
#    u'vlieland': 545,
#    u'weststellingwerf': 12845},
#   'Gelderland': {u'aalten': 13525,
#    u'apeldoorn': 77615,
#    u'arnhem': 74360,
#    u'barneveld': 26715,
#    u'berkelland': 22530,
#    u'beuningen': 12630,
#    u'bronckhorst': 18475,
#    u'brummen': 10500,
#    u'buren': 12975,
#    u'culemborg': 13745,
#    u'doesburg': 5645,
#    u'doetinchem': 27865,
#    u'druten': 9035,
#    u'duiven': 12515,
#    u'ede': 53875,
#    u'elburg': 11135,
#    u'epe': 15975,
#    u'ermelo': 12885,
#    u'geldermalsen': 13005,
#    u'groesbeek': 9320,
#    u'harderwijk': 22460,
#    u'hattem': 5755,
#    u'heerde': 9045,
#    u'heumen': 8160,
#    u'lingewaal': 5480,
#    u'lingewaard': 22735,
#    u'lochem': 16340,
#    u'maasdriel': 12160,
#    u'millingen aan de rijn': 2945,
#    u'montferland': 17365,
#    u'neder-betuwe': 11230,
#    u'neerijnen': 6055,
#    u'nijkerk': 20090,
#    u'nijmegen': 79620,
#    u'nunspeet': 13130,
#    u'oldebroek': 11475,
#    u'oost gelre': 15220,
#    u'oude ijsselstreek': 19895,
#    u'overbetuwe': 23085,
#    u'putten': 11900,
#    u'renkum': 15290,
#    u'rheden': 21300,
#    u'rijnwaarden': 5455,
#    u'rozendaal': 745,
#    u'scherpenzeel': 4640,
#    u'tiel': 20775,
#    u'ubbergen': 4700,
#    u'voorst': 11880,
#    u'wageningen': 18020,
#    u'west maas en waal': 9155,
#    u'westervoort': 7525,
#    u'wijchen': 20230,
#    u'winterswijk': 14415,
#    u'zaltbommel': 13500,
#    u'zevenaar': 15945,
#    u'zutphen': 23065},
#   'Groningen': {u'appingedam': 5835,
#    u'bedum': 5280,
#    u'bellingwedde': 4490,
#    u'de marne': 5260,
#    u'delfzijl': 13030,
#    u'eemsmond': 8215,
#    u'groningen': 96980,
#    u'grootegast': 6230,
#    u'haren': 8815,
#    u'hoogezand-sappemeer': 17040,
#    u'leek': 9720,
#    u'loppersum': 5205,
#    u'marum': 5310,
#    u'menterwolde': 6280,
#    u'oldambt': 19125,
#    u'pekela': 6430,
#    u'slochteren': 7935,
#    u'stadskanaal': 16250,
#    u'ten boer': 3755,
#    u'veendam': 13815,
#    u'vlagtwedde': 8025,
#    u'winsum': 6910,
#    u'zuidhorn': 9315},
#   'Limburg': {u'beek': 7950,
#    u'beesel': 6880,
#    u'bergen (l.)': 6655,
#    u'brunssum': 14140,
#    u'echt-susteren': 16035,
#    u'eijsden-margraten': 12515,
#    u'gennep': 8845,
#    u'gulpen-wittem': 7250,
#    u'heerlen': 43920,
#    u'horst aan de maas': 21085,
#    u'kerkrade': 23530,
#    u'landgraaf': 18685,
#    u'leudal': 18430,
#    u'maasgouw': 12040,
#    u'maastricht': 58565,
#    u'meerssen': 9550,
#    u'mook en middelaar': 3890,
#    u'nederweert': 8450,
#    u'nuth': 7675,
#    u'onderbanken': 3940,
#    u'peel en maas': 21975,
#    u'roerdalen': 10500,
#    u'roermond': 28020,
#    u'schinnen': 6435,
#    u'simpelveld': 5410,
#    u'sittard-geleen': 46290,
#    u'stein': 12625,
#    u'vaals': 4835,
#    u'valkenburg aan de geul': 8330,
#    u'venlo': 49705,
#    u'venray': 21685,
#    u'voerendaal': 6290,
#    u'weert': 24305},
#   'Noord-Brabant': {u"'s-hertogenbosch": 70275,
#    u'aalburg': 6460,
#    u'alphen-chaam': 4880,
#    u'asten': 8435,
#    u'baarle-nassau': 3405,
#    u'bergeijk': 9215,
#    u'bergen op zoom': 32745,
#    u'bernheze': 15040,
#    u'best': 14350,
#    u'bladel': 9970,
#    u'boekel': 5140,
#    u'boxmeer': 14090,
#    u'boxtel': 15095,
#    u'breda': 87030,
#    u'cranendonck': 10260,
#    u'cuijk': 12355,
#    u'deurne': 15970,
#    u'dongen': 12590,
#    u'drimmelen': 13385,
#    u'eersel': 9225,
#    u'eindhoven': 111330,
#    u'etten-leur': 20905,
#    u'geertruidenberg': 10695,
#    u'geldrop-mierlo': 19210,
#    u'gemert-bakel': 14680,
#    u'gilze en rijen': 13015,
#    u'goirle': 11345,
#    u'grave': 6570,
#    u'haaren': 6975,
#    u'halderberge': 14495,
#    u'heeze-leende': 7765,
#    u'helmond': 44675,
#    u'heusden': 21600,
#    u'hilvarenbeek': 7630,
#    u'laarbeek': 11020,
#    u'landerd': 7765,
#    u'loon op zand': 11430,
#    u'maasdonk': 5620,
#    u'mill en sint hubert': 5535,
#    u'moerdijk': 18295,
#    u'nuenen, gerwen en nederwetten': 11245,
#    u'oirschot': 9080,
#    u'oisterwijk': 12690,
#    u'oosterhout': 26455,
#    u'oss': 42380,
#    u'reusel-de mierden': 6465,
#    u'roosendaal': 38085,
#    u'rucphen': 11130,
#    u'schijndel': 11630,
#    u'sint anthonis': 6055,
#    u'sint-michielsgestel': 14090,
#    u'sint-oedenrode': 8940,
#    u'someren': 9460,
#    u'son en breugel': 7975,
#    u'steenbergen': 11745,
#    u'tilburg': 103680,
#    u'uden': 20295,
#    u'valkenswaard': 15120,
#    u'veghel': 18820,
#    u'veldhoven': 22010,
#    u'vught': 12660,
#    u'waalre': 8265,
#    u'waalwijk': 23105,
#    u'werkendam': 13150,
#    u'woensdrecht': 10855,
#    u'woudrichem': 7230,
#    u'zundert': 10895},
#   'Noord-Holland': {u'aalsmeer': 15175,
#    u'alkmaar': 46550,
#    u'amstelveen': 40225,
#    u'amsterdam': 393260,
#    u'beemster': 4395,
#    u'bergen (nh.)': 14680,
#    u'beverwijk': 19860,
#    u'blaricum': 4390,
#    u'bloemendaal': 10535,
#    u'bussum': 15550,
#    u'castricum': 16845,
#    u'den helder': 28190,
#    u'diemen': 12225,
#    u'drechterland': 9790,
#    u'edam-volendam': 14350,
#    u'enkhuizen': 9185,
#    u'graft-de rijp': 3225,
#    u'haarlem': 74655,
#    u'haarlemmerliede en spaarnwoude': 2730,
#    u'haarlemmermeer': 71710,
#    u'heemskerk': 19210,
#    u'heemstede': 12370,
#    u'heerhugowaard': 26615,
#    u'heiloo': 11130,
#    u'hilversum': 41935,
#    u'hollands kroon': 24085,
#    u'hoorn': 35105,
#    u'huizen': 20165,
#    u'koggenland': 11230,
#    u'landsmeer': 5010,
#    u'langedijk': 13430,
#    u'laren': 5080,
#    u'medemblik': 22030,
#    u'muiden': 3110,
#    u'naarden': 8315,
#    u'oostzaan': 4465,
#    u'opmeer': 5725,
#    u'ouder-amstel': 6455,
#    u'purmerend': 38885,
#    u'schagen': 23125,
#    u'schermer': 2800,
#    u'stede broec': 10840,
#    u'texel': 6765,
#    u'uitgeest': 6555,
#    u'uithoorn': 13970,
#    u'velsen': 33280,
#    u'waterland': 8505,
#    u'weesp': 8790,
#    u'wijdemeren': 11355,
#    u'wormerland': 7860,
#    u'zaanstad': 74000,
#    u'zandvoort': 7955,
#    u'zeevang': 3160},
#   'Overijssel': {u'almelo': 36125,
#    u'borne': 10845,
#    u'dalfsen': 13985,
#    u'deventer': 48545,
#    u'dinkelland': 13235,
#    u'enschede': 80450,
#    u'haaksbergen': 12230,
#    u'hardenberg': 30155,
#    u'hellendoorn': 17870,
#    u'hengelo': 40325,
#    u'hof van twente': 17465,
#    u'kampen': 25295,
#    u'losser': 11330,
#    u'oldenzaal': 16075,
#    u'olst-wijhe': 8965,
#    u'ommen': 8665,
#    u'raalte': 18305,
#    u'rijssen-holten': 18695,
#    u'staphorst': 8340,
#    u'steenwijkerland': 21735,
#    u'tubbergen': 10785,
#    u'twenterand': 17225,
#    u'wierden': 11895,
#    u'zwartewaterland': 11210,
#    u'zwolle': 59915},
#   'Utrecht': {u'amersfoort': 73525,
#    u'baarn': 11675,
#    u'bunnik': 7195,
#    u'bunschoten': 10180,
#    u'de bilt': 19990,
#    u'de ronde venen': 21300,
#    u'eemnes': 4365,
#    u'houten': 23895,
#    u'ijsselstein': 16680,
#    u'leusden': 14185,
#    u'lopik': 7115,
#    u'montfoort': 6840,
#    u'nieuwegein': 30155,
#    u'oudewater': 4855,
#    u'renswoude': 2445,
#    u'rhenen': 9430,
#    u'soest': 22195,
#    u'stichtse vecht': 31085,
#    u'utrecht': 156220,
#    u'utrechtse heuvelrug': 23230,
#    u'veenendaal': 30955,
#    u'vianen': 9680,
#    u'wijk bij duurstede': 11385,
#    u'woerden': 24910,
#    u'woudenberg': 6160,
#    u'zeist': 29675},
#   'Zeeland': {u'borsele': 11460,
#    u'goes': 18090,
#    u'hulst': 13725,
#    u'kapelle': 6215,
#    u'middelburg': 23045,
#    u'noord-beveland': 3760,
#    u'reimerswaal': 10975,
#    u'schouwen-duiveland': 16835,
#    u'sluis': 11720,
#    u'terneuzen': 27215,
#    u'tholen': 12745,
#    u'veere': 10950,
#    u'vlissingen': 22130},
#   'Zuid-Holland': {u"'s-gravenhage": 249735,
#    u'alblasserdam': 9610,
#    u'albrandswaard': 12455,
#    u'alphen aan den rijn': 36015,
#    u'barendrecht': 23325,
#    u'bergambacht': 4890,
#    u'bernisse': 6210,
#    u'binnenmaas': 14380,
#    u'bodegraven-reeuwijk': 16390,
#    u'boskoop': 7570,
#    u'brielle': 8000,
#    u'capelle aan den ijssel': 31890,
#    u'cromstrijen': 6330,
#    u'delft': 52635,
#    u'dordrecht': 58380,
#    u'giessenlanden': 7355,
#    u'goeree-overflakkee': 23885,
#    u'gorinchem': 17280,
#    u'gouda': 34705,
#    u'hardinxveld-giessendam': 8825,
#    u'hellevoetsluis': 19420,
#    u'hendrik-ido-ambacht': 14075,
#    u'hillegom': 10310,
#    u'kaag en braassem': 13030,
#    u'katwijk': 31125,
#    u'korendijk': 5385,
#    u'krimpen aan den ijssel': 14040,
#    u'lansingerland': 28125,
#    u'leerdam': 10170,
#    u'leiden': 58225,
#    u'leiderdorp': 12910,
#    u'leidschendam-voorburg': 34715,
#    u'lisse': 11045,
#    u'maassluis': 15695,
#    u'midden-delfland': 9220,
#    u'molenwaard': 14835,
#    u'nederlek': 6965,
#    u'nieuwkoop': 13735,
#    u'noordwijk': 12895,
#    u'noordwijkerhout': 7930,
#    u'oegstgeest': 11180,
#    u'oud-beijerland': 11480,
#    u'ouderkerk': 4030,
#    u'papendrecht': 15750,
#    u'pijnacker-nootdorp': 25150,
#    u'ridderkerk': 21895,
#    u'rijnwoude': 9335,
#    u'rijswijk': 22395,
#    u'rotterdam': 303255,
#    u'schiedam': 37445,
#    u'schoonhoven': 5860,
#    u'sliedrecht': 11960,
#    u'spijkenisse': 35405,
#    u'strijen': 4395,
#    u'teylingen': 17845,
#    u'vlaardingen': 34610,
#    u'vlist': 4865,
#    u'voorschoten': 11910,
#    u'waddinxveen': 12540,
#    u'wassenaar': 12135,
#    u'westland': 51065,
#    u'westvoorne': 6875,
#    u'zederik': 6740,
#    u'zoetermeer': 60285,
#    u'zoeterwoude': 4015,
#    u'zuidplas': 20240,
#    u'zwijndrecht': 21645}},
#  '2014': {'Drenthe': {u'aa en hunze': 12600,
#    u'assen': 32990,
#    u'borger-odoorn': 12795,
#    u'coevorden': 17760,
#    u'de wolden': 11800,
#    u'emmen': 53470,
#    u'hoogeveen': 27175,
#    u'meppel': 16075,
#    u'midden-drenthe': 16650,
#    u'noordenveld': 15460,
#    u'tynaarlo': 16005,
#    u'westerveld': 9445},
#   'Flevoland': {u'almere': 97235,
#    u'dronten': 20460,
#    u'lelystad': 38000,
#    u'noordoostpolder': 23465,
#    u'urk': 9840,
#    u'zeewolde': 10940},
#   'Friesland': {u'achtkarspelen': 14255,
#    u'ameland': 1755,
#    u'dantumadiel': 9540,
#    u'de friese meren': 25890,
#    u'dongeradeel': 12080,
#    u'ferwerderadiel': 4470,
#    u'franekeradeel': 10270,
#    u'harlingen': 7935,
#    u'heerenveen': 24610,
#    u'het bildt': 5435,
#    u'kollumerland en nieuwkruisland': 6620,
#    u'leeuwarden': 52950,
#    u'leeuwarderadeel': 5135,
#    u'littenseradiel': 5570,
#    u'menameradiel': 6985,
#    u'ooststellingwerf': 12860,
#    u'opsterland': 14910,
#    u'schiermonnikoog': 475,
#    u'smallingerland': 27595,
#    u's\xfadwest-frysl\xe2n': 42075,
#    u'terschelling': 2535,
#    u'tytsjerksteradiel': 15950,
#    u'vlieland': 540,
#    u'weststellingwerf': 12775},
#   'Gelderland': {u'aalten': 13505,
#    u'apeldoorn': 77795,
#    u'arnhem': 75030,
#    u'barneveld': 26955,
#    u'berkelland': 22470,
#    u'beuningen': 12630,
#    u'bronckhorst': 18370,
#    u'brummen': 10475,
#    u'buren': 12990,
#    u'culemborg': 13680,
#    u'doesburg': 5600,
#    u'doetinchem': 27835,
#    u'druten': 9030,
#    u'duiven': 12595,
#    u'ede': 54300,
#    u'elburg': 11205,
#    u'epe': 15985,
#    u'ermelo': 12880,
#    u'geldermalsen': 13015,
#    u'groesbeek': 9345,
#    u'harderwijk': 22500,
#    u'hattem': 5755,
#    u'heerde': 9090,
#    u'heumen': 8120,
#    u'lingewaal': 5500,
#    u'lingewaard': 22730,
#    u'lochem': 16320,
#    u'maasdriel': 12210,
#    u'millingen aan de rijn': 2940,
#    u'montferland': 17495,
#    u'neder-betuwe': 11270,
#    u'neerijnen': 6060,
#    u'nijkerk': 20230,
#    u'nijmegen': 80680,
#    u'nunspeet': 13155,
#    u'oldebroek': 11495,
#    u'oost gelre': 15105,
#    u'oude ijsselstreek': 19830,
#    u'overbetuwe': 23180,
#    u'putten': 11850,
#    u'renkum': 15300,
#    u'rheden': 21305,
#    u'rijnwaarden': 5425,
#    u'rozendaal': 740,
#    u'scherpenzeel': 4685,
#    u'tiel': 20770,
#    u'ubbergen': 4695,
#    u'voorst': 11875,
#    u'wageningen': 18015,
#    u'west maas en waal': 9145,
#    u'westervoort': 7450,
#    u'wijchen': 20305,
#    u'winterswijk': 14395,
#    u'zaltbommel': 13630,
#    u'zevenaar': 15825,
#    u'zutphen': 23040},
#   'Groningen': {u'appingedam': 5845,
#    u'bedum': 5245,
#    u'bellingwedde': 4450,
#    u'de marne': 5180,
#    u'delfzijl': 12860,
#    u'eemsmond': 8145,
#    u'groningen': 98425,
#    u'grootegast': 6210,
#    u'haren': 8925,
#    u'hoogezand-sappemeer': 16950,
#    u'leek': 9690,
#    u'loppersum': 5155,
#    u'marum': 5310,
#    u'menterwolde': 6220,
#    u'oldambt': 19045,
#    u'pekela': 6390,
#    u'slochteren': 7910,
#    u'stadskanaal': 16185,
#    u'ten boer': 3730,
#    u'veendam': 13770,
#    u'vlagtwedde': 7910,
#    u'winsum': 6870,
#    u'zuidhorn': 9375},
#   'Limburg': {u'beek': 7890,
#    u'beesel': 6860,
#    u'bergen (l.)': 6640,
#    u'brunssum': 14115,
#    u'echt-susteren': 16000,
#    u'eijsden-margraten': 12500,
#    u'gennep': 8810,
#    u'gulpen-wittem': 7270,
#    u'heerlen': 43780,
#    u'horst aan de maas': 20975,
#    u'kerkrade': 23325,
#    u'landgraaf': 18495,
#    u'leudal': 18315,
#    u'maasgouw': 11985,
#    u'maastricht': 58855,
#    u'meerssen': 9480,
#    u'mook en middelaar': 3860,
#    u'nederweert': 8435,
#    u'nuth': 7695,
#    u'onderbanken': 3925,
#    u'peel en maas': 21950,
#    u'roerdalen': 10420,
#    u'roermond': 28125,
#    u'schinnen': 6435,
#    u'simpelveld': 5375,
#    u'sittard-geleen': 46125,
#    u'stein': 12610,
#    u'vaals': 4780,
#    u'valkenburg aan de geul': 8230,
#    u'venlo': 49890,
#    u'venray': 21770,
#    u'voerendaal': 6195,
#    u'weert': 24335},
#   'Noord-Brabant': {u"'s-hertogenbosch": 70855,
#    u'aalburg': 6490,
#    u'alphen-chaam': 4920,
#    u'asten': 8455,
#    u'baarle-nassau': 3355,
#    u'bergeijk': 9255,
#    u'bergen op zoom': 32880,
#    u'bernheze': 14960,
#    u'best': 14335,
#    u'bladel': 10055,
#    u'boekel': 5160,
#    u'boxmeer': 14070,
#    u'boxtel': 15060,
#    u'breda': 87795,
#    u'cranendonck': 10260,
#    u'cuijk': 12375,
#    u'deurne': 15895,
#    u'dongen': 12605,
#    u'drimmelen': 13330,
#    u'eersel': 9185,
#    u'eindhoven': 112765,
#    u'etten-leur': 20965,
#    u'geertruidenberg': 10715,
#    u'geldrop-mierlo': 19300,
#    u'gemert-bakel': 14810,
#    u'gilze en rijen': 13070,
#    u'goirle': 11430,
#    u'grave': 6560,
#    u'haaren': 6975,
#    u'halderberge': 14565,
#    u'heeze-leende': 7765,
#    u'helmond': 44770,
#    u'heusden': 21615,
#    u'hilvarenbeek': 7625,
#    u'laarbeek': 11010,
#    u'landerd': 7770,
#    u'loon op zand': 11420,
#    u'maasdonk': 5660,
#    u'mill en sint hubert': 5510,
#    u'moerdijk': 18375,
#    u'nuenen, gerwen en nederwetten': 11230,
#    u'oirschot': 9080,
#    u'oisterwijk': 12695,
#    u'oosterhout': 26435,
#    u'oss': 42435,
#    u'reusel-de mierden': 6510,
#    u'roosendaal': 38035,
#    u'rucphen': 11125,
#    u'schijndel': 11705,
#    u'sint anthonis': 6030,
#    u'sint-michielsgestel': 14125,
#    u'sint-oedenrode': 8935,
#    u'someren': 9495,
#    u'son en breugel': 8020,
#    u'steenbergen': 11740,
#    u'tilburg': 104595,
#    u'uden': 20275,
#    u'valkenswaard': 14985,
#    u'veghel': 18820,
#    u'veldhoven': 22005,
#    u'vught': 12720,
#    u'waalre': 8275,
#    u'waalwijk': 23155,
#    u'werkendam': 13165,
#    u'woensdrecht': 10845,
#    u'woudrichem': 7210,
#    u'zundert': 10985},
#   'Noord-Holland': {u'aalsmeer': 15220,
#    u'alkmaar': 46750,
#    u'amstelveen': 40455,
#    u'amsterdam': 399425,
#    u'beemster': 4455,
#    u'bergen (nh.)': 14555,
#    u'beverwijk': 19855,
#    u'blaricum': 4395,
#    u'bloemendaal': 10490,
#    u'bussum': 15580,
#    u'castricum': 16795,
#    u'den helder': 27990,
#    u'diemen': 12615,
#    u'drechterland': 9735,
#    u'edam-volendam': 14450,
#    u'enkhuizen': 9235,
#    u'graft-de rijp': 3240,
#    u'haarlem': 75780,
#    u'haarlemmerliede en spaarnwoude': 2720,
#    u'haarlemmermeer': 71700,
#    u'heemskerk': 19150,
#    u'heemstede': 12360,
#    u'heerhugowaard': 26835,
#    u'heiloo': 11110,
#    u'hilversum': 42165,
#    u'hollands kroon': 24030,
#    u'hoorn': 35310,
#    u'huizen': 20045,
#    u'koggenland': 11290,
#    u'landsmeer': 5005,
#    u'langedijk': 13440,
#    u'laren': 5085,
#    u'medemblik': 22025,
#    u'muiden': 3055,
#    u'naarden': 8280,
#    u'oostzaan': 4465,
#    u'opmeer': 5745,
#    u'ouder-amstel': 6450,
#    u'purmerend': 38875,
#    u'schagen': 23035,
#    u'schermer': 2825,
#    u'stede broec': 10820,
#    u'texel': 6725,
#    u'uitgeest': 6625,
#    u'uithoorn': 14020,
#    u'velsen': 33340,
#    u'waterland': 8495,
#    u'weesp': 8770,
#    u'wijdemeren': 11345,
#    u'wormerland': 7860,
#    u'zaanstad': 74455,
#    u'zandvoort': 7965,
#    u'zeevang': 3170},
#   'Overijssel': {u'almelo': 36005,
#    u'borne': 10895,
#    u'dalfsen': 14015,
#    u'deventer': 48455,
#    u'dinkelland': 13245,
#    u'enschede': 80425,
#    u'haaksbergen': 12245,
#    u'hardenberg': 30135,
#    u'hellendoorn': 17860,
#    u'hengelo': 40375,
#    u'hof van twente': 17380,
#    u'kampen': 25365,
#    u'losser': 11345,
#    u'oldenzaal': 16035,
#    u'olst-wijhe': 8985,
#    u'ommen': 8735,
#    u'raalte': 18345,
#    u'rijssen-holten': 18725,
#    u'staphorst': 8375,
#    u'steenwijkerland': 21660,
#    u'tubbergen': 10805,
#    u'twenterand': 17195,
#    u'wierden': 11955,
#    u'zwartewaterland': 11240,
#    u'zwolle': 60385},
#   'Utrecht': {u'amersfoort': 74175,
#    u'baarn': 11715,
#    u'bunnik': 7230,
#    u'bunschoten': 10260,
#    u'de bilt': 20010,
#    u'de ronde venen': 21155,
#    u'eemnes': 4340,
#    u'houten': 23915,
#    u'ijsselstein': 16720,
#    u'leusden': 14250,
#    u'lopik': 7110,
#    u'montfoort': 6835,
#    u'nieuwegein': 30300,
#    u'oudewater': 4855,
#    u'renswoude': 2460,
#    u'rhenen': 9470,
#    u'soest': 22155,
#    u'stichtse vecht': 31250,
#    u'utrecht': 159305,
#    u'utrechtse heuvelrug': 23235,
#    u'veenendaal': 31050,
#    u'vianen': 9655,
#    u'wijk bij duurstede': 11365,
#    u'woerden': 24970,
#    u'woudenberg': 6225,
#    u'zeist': 29635},
#   'Zeeland': {u'borsele': 11410,
#    u'goes': 18035,
#    u'hulst': 13655,
#    u'kapelle': 6210,
#    u'middelburg': 23145,
#    u'noord-beveland': 3770,
#    u'reimerswaal': 11010,
#    u'schouwen-duiveland': 16750,
#    u'sluis': 11745,
#    u'terneuzen': 27180,
#    u'tholen': 12680,
#    u'veere': 10930,
#    u'vlissingen': 22135},
#   'Zuid-Holland': {u"'s-gravenhage": 251305,
#    u'alblasserdam': 9690,
#    u'albrandswaard': 12450,
#    u'alphen aan den rijn': 52980,
#    u'barendrecht': 23330,
#    u'bergambacht': 4930,
#    u'bernisse': 6165,
#    u'binnenmaas': 14215,
#    u'bodegraven-reeuwijk': 16405,
#    u'brielle': 7990,
#    u'capelle aan den ijssel': 31970,
#    u'cromstrijen': 6330,
#    u'delft': 53390,
#    u'dordrecht': 58555,
#    u'giessenlanden': 7340,
#    u'goeree-overflakkee': 23855,
#    u'gorinchem': 17380,
#    u'gouda': 34730,
#    u'hardinxveld-giessendam': 8835,
#    u'hellevoetsluis': 19345,
#    u'hendrik-ido-ambacht': 14205,
#    u'hillegom': 10390,
#    u'kaag en braassem': 13050,
#    u'katwijk': 31215,
#    u'korendijk': 5350,
#    u'krimpen aan den ijssel': 14005,
#    u'lansingerland': 28370,
#    u'leerdam': 10100,
#    u'leiden': 58890,
#    u'leiderdorp': 12935,
#    u'leidschendam-voorburg': 35090,
#    u'lisse': 11005,
#    u'maassluis': 15710,
#    u'midden-delfland': 9330,
#    u'molenwaard': 14745,
#    u'nederlek': 6935,
#    u'nieuwkoop': 13770,
#    u'noordwijk': 12885,
#    u'noordwijkerhout': 8015,
#    u'oegstgeest': 11020,
#    u'oud-beijerland': 11595,
#    u'ouderkerk': 4060,
#    u'papendrecht': 15790,
#    u'pijnacker-nootdorp': 25450,
#    u'ridderkerk': 21870,
#    u'rijswijk': 22550,
#    u'rotterdam': 304350,
#    u'schiedam': 37605,
#    u'schoonhoven': 5865,
#    u'sliedrecht': 12060,
#    u'spijkenisse': 35525,
#    u'strijen': 4340,
#    u'teylingen': 17810,
#    u'vlaardingen': 34600,
#    u'vlist': 4840,
#    u'voorschoten': 12040,
#    u'waddinxveen': 12700,
#    u'wassenaar': 12140,
#    u'westland': 51410,
#    u'westvoorne': 6900,
#    u'zederik': 6830,
#    u'zoetermeer': 60400,
#    u'zoeterwoude': 4010,
#    u'zuidplas': 20270,
#    u'zwijndrecht': 21640}}}
