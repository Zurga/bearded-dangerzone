# %%
import json
# !ls
data = []
with open('build/gem_geo2.json') as j:
    data.append(json.loads(j.readline()))
# Out:
# README.md                 convert                   node_modules
# Untitled.ipynb            css                       package.json
# bearded-dangerzone.esproj index.html                slidertest.html
# build                     js                        test.html

# %%
data[0]
data[]
# Out:
# {u'features': [{u'geometry': {u'geometries': [{u'coordinates': [[[6.874372134595468,
#          53.407963990764834],
#         [6.86199360838002, 53.41160963765416],
#         [6.843425819056847, 53.42226614394603],
#         [6.792364398418122, 53.403477040747205],
#         [6.788109280031561, 53.407963990764834],
#         [6.784240990589233, 53.40740312201263],
#         [6.782693674812302, 53.410487900149754],
#         [6.778438556425742, 53.410768334525855],
#         [6.769541490708388, 53.403477040747205],
#         [6.7486527277198185, 53.395344443840244],
#         [6.727377135787016, 53.37964011877854],
#         [6.696817649192628, 53.36281405621242],
#         [6.68443912297718, 53.367020571853956],
#         [6.681344491423317, 53.365898834349544],
#         [6.6767025440925245, 53.367020571853956],
#         [6.671286938873266, 53.36505753122124],
#         [6.664324017877075, 53.367020571853956],
#         [6.6519454916616265, 53.36449666246904],
# ...
